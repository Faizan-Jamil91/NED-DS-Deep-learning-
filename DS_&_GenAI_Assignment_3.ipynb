# %% [markdown]
# <a href="https://colab.research.google.com/github/Faizan-Jamil91/NED-DS-Deep-learning-/blob/main/DS_%26_GenAI_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/bin/bash
# !kaggle datasets download msambare/fer2013
# Out:
# Dataset URL: https://www.kaggle.com/datasets/msambare/fer2013
# License(s): DbCL-1.0
# Downloading fer2013.zip to /content
#  93% 56.0M/60.3M [00:00<00:00, 116MB/s]
# 100% 60.3M/60.3M [00:00<00:00, 96.4MB/s]

# %%
import zipfile

# Path to the ZIP file
zip_path = '/content/fer2013.zip'
extract_path = '/content/fer2013'

# Unzipping the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f"Files extracted to: {extract_path}")
# Out:
# Files extracted to: /content/fer2013

# %%
import os

# List the extracted files
extracted_files = os.listdir(extract_path)
print("Extracted files:", extracted_files)
# Out:
# Extracted files: ['test', 'train']

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
# Paths to train and test directories
train_dir = '/content/fer2013/train'
test_dir = '/content/fer2013/test'

# %%
# Image size and batch size
img_size = (48, 48)
batch_size = 64

# %%
# Data augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,  # Normalize to [0, 1]
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2  # Split training data into train and validation sets
)

test_datagen = ImageDataGenerator(rescale=1.0 / 255.0)

# %%
# Training and validation data generators
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.

# %%
# Test data generator
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='categorical'
)
# Out:
# Found 7178 images belonging to 7 classes.

# %%
# Build the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(7, activation='softmax')  # 7 categories for emotion
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Train the model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=25,  # Adjust epochs based on performance and time
    verbose=1
)
# Out:
# Epoch 1/25
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 42s 96ms/step - accuracy: 0.2319 - loss: 1.8357 - val_accuracy: 0.2552 - val_loss: 1.7947
# Epoch 2/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.2524 - loss: 1.8008 - val_accuracy: 0.2675 - val_loss: 1.7746
# Epoch 3/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 40s 58ms/step - accuracy: 0.2632 - loss: 1.7720 - val_accuracy: 0.2576 - val_loss: 1.7683
# Epoch 4/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.2688 - loss: 1.7614 - val_accuracy: 0.2787 - val_loss: 1.7382
# Epoch 5/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.2800 - loss: 1.7423 - val_accuracy: 0.2959 - val_loss: 1.7219
# Epoch 6/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - accuracy: 0.3027 - loss: 1.7225 - val_accuracy: 0.3020 - val_loss: 1.6941
# Epoch 7/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 40s 59ms/step - accuracy: 0.3116 - loss: 1.6996 - val_accuracy: 0.3210 - val_loss: 1.6714
# Epoch 8/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 59ms/step - accuracy: 0.3284 - loss: 1.6831 - val_accuracy: 0.3581 - val_loss: 1.6179
# Epoch 9/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 58ms/step - accuracy: 0.3409 - loss: 1.6432 - val_accuracy: 0.3726 - val_loss: 1.5972
# Epoch 10/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 42s 60ms/step - accuracy: 0.3563 - loss: 1.6204 - val_accuracy: 0.3809 - val_loss: 1.5627
# Epoch 11/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 59ms/step - accuracy: 0.3737 - loss: 1.5907 - val_accuracy: 0.3916 - val_loss: 1.5403
# Epoch 12/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 40s 57ms/step - accuracy: 0.3879 - loss: 1.5630 - val_accuracy: 0.4102 - val_loss: 1.5061
# Epoch 13/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.3942 - loss: 1.5528 - val_accuracy: 0.4285 - val_loss: 1.4874
# Epoch 14/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.4121 - loss: 1.5299 - val_accuracy: 0.4292 - val_loss: 1.4634
# Epoch 15/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 59ms/step - accuracy: 0.4226 - loss: 1.5006 - val_accuracy: 0.4398 - val_loss: 1.4453
# Epoch 16/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - accuracy: 0.4112 - loss: 1.5092 - val_accuracy: 0.4504 - val_loss: 1.4301
# Epoch 17/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.4216 - loss: 1.4936 - val_accuracy: 0.4372 - val_loss: 1.4507
# Epoch 18/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - accuracy: 0.4241 - loss: 1.4926 - val_accuracy: 0.4543 - val_loss: 1.4180
# Epoch 19/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.4314 - loss: 1.4712 - val_accuracy: 0.4607 - val_loss: 1.4099
# Epoch 20/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 40s 54ms/step - accuracy: 0.4343 - loss: 1.4519 - val_accuracy: 0.4633 - val_loss: 1.3993
# Epoch 21/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.4369 - loss: 1.4657 - val_accuracy: 0.4673 - val_loss: 1.3929
# Epoch 22/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 40s 55ms/step - accuracy: 0.4312 - loss: 1.4639 - val_accuracy: 0.4745 - val_loss: 1.3707
# Epoch 23/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 62ms/step - accuracy: 0.4536 - loss: 1.4361 - val_accuracy: 0.4543 - val_loss: 1.4065
# Epoch 24/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.4503 - loss: 1.4260 - val_accuracy: 0.4816 - val_loss: 1.3584
# Epoch 25/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.4559 - loss: 1.4260 - val_accuracy: 0.4813 - val_loss: 1.3608

# %%
# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(test_generator, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Test Loss: 1.2268
# Test Accuracy: 0.5351

# %%
# Plot training and validation performance
plt.figure(figsize=(12, 5))

# Loss graph
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy graph
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Save the model
model.save('fer2013_emotion_recognition_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
